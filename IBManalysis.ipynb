# %%
import pandas as pd
import requests 
from io import StringIO

# %%
url = 'https://raw.githubusercontent.com/Dylan-VanBrunt/Ibm_Analysis/main/ibmstock_price.csv'

# Use requests to get the content
response = requests.get(url, verify=False)  # Warning: setting verify=False will ignore SSL errors

# Convert the content to a pandas DataFrame
data = StringIO(response.text)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1099: InsecureRequestWarning: Unverified HTTPS request is being made to host 'raw.githubusercontent.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
#downloaded data from mergent online  
#pricedata = pd.read_csv("ibmstock_price.csv")
balancesheet = pd.read_csv("https://raw.githubusercontent.com/Dylan-VanBrunt/Ibm_Analysis/main/ibmstock_price.csv")#
#income = pd.read_csv("ibm_incomestatements.csv")
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/urllib/request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1319, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1318 """Send a complete request to the server."""
# -> 1319 self._send_request(method, url, body, headers, encode_chunked)
#
# ...

# %%
balancedata = pd.DataFrame(balancesheet)

# %%
balancedata
# Out:
#                                   Powered by Clearbit     Unnamed: 1  \
# 0     International Business Machines Corp (NYS: IBM)            NaN
# 1                                                 NaN            NaN
# 2   Exchange rate used is that of the Year End rep...            NaN
# 3                                                 NaN            NaN
# 4                                                 NaN            NaN
# 5               Standardized Quarterly Balance Sheet             NaN
# 6                                         Report Date     12/31/2023
# 7                                                 NaN    4th Quarter
# 8                                            Currency            USD
# 9                                        Audit Status  Not Qualified
# 10                                       Consolidated            Yes
# 11                                              Scale      Thousands
# 12                                 Cash & Equivalents       13089000
# ...
